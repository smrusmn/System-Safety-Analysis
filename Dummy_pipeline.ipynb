# %% [markdown]
# ## **Dummy Data Testing**

# %%
# importing dependencies
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.svm import SVC

# %%
df = pd.read_csv('Dummy.csv')
df.head()
# Out:
#   Function Failure_Condition_A Failure_Condition_B Redundancy    Phase  \
# 0        A          Annuciated          Total Loss      three  Landing
# 1        A        Unannuciated          Total Loss      three  Landing
# 2       B           Annuciated          Total Loss        two      RTO
# 3       B         Unannuciated          Total Loss        two      RTO
# 4        C          Annuciated          Total Loss        one     Taxi
#
#             DAL  DALn  Redundancy_n
# 0  Catastrophic     1             3
# 1  Catastrophic     1             3
# 2     Hazardous     2             2
# 3     Hazardous     2             2
# 4         Major     3             1

# %%
df1 = df.drop(columns='DALn', axis=0)
df1.head()
# Out:
#   Function Failure_Condition_A Failure_Condition_B Redundancy    Phase  \
# 0        A          Annuciated          Total Loss      three  Landing
# 1        A        Unannuciated          Total Loss      three  Landing
# 2       B           Annuciated          Total Loss        two      RTO
# 3       B         Unannuciated          Total Loss        two      RTO
# 4        C          Annuciated          Total Loss        one     Taxi
#
#             DAL  Redundancy_n
# 0  Catastrophic             3
# 1  Catastrophic             3
# 2     Hazardous             2
# 3     Hazardous             2
# 4         Major             1

# %%
X = df1.drop(columns='DAL', axis=0)
X.head()
# Out:
#   Function Failure_Condition_A Failure_Condition_B Redundancy    Phase  \
# 0        A          Annuciated          Total Loss      three  Landing
# 1        A        Unannuciated          Total Loss      three  Landing
# 2       B           Annuciated          Total Loss        two      RTO
# 3       B         Unannuciated          Total Loss        two      RTO
# 4        C          Annuciated          Total Loss        one     Taxi
#
#    Redundancy_n
# 0             3
# 1             3
# 2             2
# 3             2
# 4             1

# %%
y=df1.DAL
y.head()
# Out:
# 0    Catastrophic
# 1    Catastrophic
# 2       Hazardous
# 3       Hazardous
# 4           Major
# Name: DAL, dtype: object

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=0)
X_train.shape,X_test.shape,y_train.shape, y_test.shape
# Out:
# ((12, 6), (4, 6), (12,), (4,))

# %%
X_train
# Out:
#    Function Failure_Condition_A Failure_Condition_B Redundancy    Phase  \
# 13        C        Unannuciated        Partial Loss        one     Taxi
# 4         C          Annuciated          Total Loss        one     Taxi
# 2        B           Annuciated          Total Loss        two      RTO
# 14        D          Annuciated        Partial Loss       zero   Cruise
# 10       B           Annuciated        Partial Loss        two      RTO
# 7         D        Unannuciated          Total Loss       zero   Cruise
# 15        D        Unannuciated        Partial Loss       zero   Cruise
# 11       B         Unannuciated        Partial Loss        two      RTO
# 3        B         Unannuciated          Total Loss        two      RTO
# 0         A          Annuciated          Total Loss      three  Landing
# 5         C        Unannuciated          Total Loss        one     Taxi
# 12        C          Annuciated        Partial Loss        one     Taxi
#
#     Redundancy_n
# 13             1
# 4              1
# 2              2
# 14             0
# 10             2
# 7              0
# 15             0
# 11             2
# 3              2
# 0              3
# 5              1
# 12             1

# %%
categorical_features = X.columns
numerical_features = []
categorical_features
# Out:
# Index(['Function', 'Failure_Condition_A', 'Failure_Condition_B', 'Redundancy',
#        'Phase', 'Redundancy_n'],
#       dtype='object')

# %%
# numeric_transformer = Pipeline(steps=[('scaler', StandardScaler())])
categorical_transformer = Pipeline(steps=[('onehot', OneHotEncoder())])

# %%
preprocessor = ColumnTransformer(
    transformers=[
        ('cat', categorical_transformer, categorical_features)
    ])

# %%
clf = Pipeline(steps=[('preprocessor', preprocessor),
                      ('classifier', SVC(kernel='linear'))])

# %%
clf.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('cat',
#                                                   Pipeline(steps=[('onehot',
#                                                                    OneHotEncoder())]),
#                                                   Index(['Function', 'Failure_Condition_A', 'Failure_Condition_B', 'Redundancy',
#        'Phase', 'Redundancy_n'],
#       dtype='object'))])),
#                 ('classifier', SVC(kernel='linear'))])

# %%
results = clf.predict(X_test)

# %%
accuracy = clf.score(X_test, y_test)
print(f'Test Accuracy: {accuracy}')
# Out:
# Test Accuracy: 0.75

# %%
y_test, results
# Out:
# (1    Catastrophic
#  6           Minor
#  8       Hazardous
#  9    Catastrophic
#  Name: DAL, dtype: object,
#  array(['Catastrophic', 'Minor', 'Catastrophic', 'Catastrophic'],
#        dtype=object))

# %%
correlation = df['DALn'].corr(df['Redundancy_n'])
print(f"Correlation between DAL and Redundancy: {correlation}")
# Out:
# Correlation between DAL and Redundancy: -0.8914003559538187
