# %% [markdown]
# <a href="https://colab.research.google.com/github/smrusmn/FYP_SFHA/blob/master/FYP_I_Initial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import spacy
from sklearn import svm
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
nlp = spacy.load("en_core_web_sm")
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('Sub2Sys_string.csv')
df.head()
# Out:
#   Sub_System Failure Condition_1s Failure Condition_2s Parent Condition_1s  \
# 0          A      Partial Failure           Annuciated     Partial Failure
# 1          A        Total Failure           Annuciated     Partial Failure
# 2         B       Partial Failure           Annuciated     Partial Failure
# 3         B         Total Failure           Annuciated     Partial Failure
# 4          C      Partial Failure           Annuciated     Partial Failure
#
#   Parent Condition_2s  DALs    DAL
# 0          Annuciated  None   None
# 1          Annuciated  None  Minor
# 2          Annuciated  None   None
# 3          Annuciated  None  Minor
# 4          Annuciated  None   None

# %%
df.isnull().any()
# Out:
# Sub_System              False
# Failure Condition_1s    False
# Failure Condition_2s    False
# Parent Condition_1s     False
# Parent Condition_2s     False
# DALs                    False
# DAL                     False
# dtype: bool

# %%
df.columns = df.columns.str.replace(' ', '_')
df = df.apply(lambda x: x.str.lower() if x.dtype == 'object' else x)
df.columns = df.columns.str.replace('[^\w\s]', '')
df = df.applymap(lambda x: ''.join(e for e in str(x) if e.isalnum() or e.isspace()) if isinstance(x, str) else x)
df.head()
# Out:
# <ipython-input-4-34e902a18787>:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   df.columns = df.columns.str.replace('[^\w\s]', '')
#   Sub_System Failure_Condition_1s Failure_Condition_2s Parent_Condition_1s  \
# 0          a      partial failure           annuciated     partial failure
# 1          a        total failure           annuciated     partial failure
# 2         b       partial failure           annuciated     partial failure
# 3         b         total failure           annuciated     partial failure
# 4          c      partial failure           annuciated     partial failure
#
#   Parent_Condition_2s  DALs    DAL
# 0          annuciated  none   none
# 1          annuciated  none  minor
# 2          annuciated  none   none
# 3          annuciated  none  minor
# 4          annuciated  none   none

# %%
X = df.drop('DAL', axis = 'columns')
X.head()
y = df.DAL
y.head()
# Out:
# 0     none
# 1    minor
# 2     none
# 3    minor
# 4     none
# Name: DAL, dtype: object

# %%
df.columns
# Out:
# Index(['Sub_System', 'Failure_Condition_1s', 'Failure_Condition_2s',
#        'Parent_Condition_1s', 'Parent_Condition_2s', 'DALs', 'DAL'],
#       dtype='object')

# %%
docs = [nlp(text) for text in (df['Sub_System'])]
# print(docs)
x1_vecs = []
trf = spacy.load('en_core_web_sm')
for doc in trf.pipe(df['Sub_System']):
  a = doc.vector
  x1_vecs.append(a)
print(docs)
# print(x1_vecs)
# Out:
# [a, a, b , b , c, c, d, d, a, a, b , b , c, c, d, d, a, a, b , b , c, c, d, d, a, a, b , b , c, c, d, d, a, a, b , b , c, c, d, d, a, a, b , b , c, c, d, d, a, a, b , b , c, c, d, d, a, a, b , b , c, c, d, d]

# %%
docs = [nlp(text) for text in (df['Failure_Condition_1s'])]
# print(docs)
x2_vecs = []
trf = spacy.load('en_core_web_sm')
for doc in trf.pipe(df['Failure_Condition_1s']):
  a = doc.vector
  x2_vecs.append(a)
print(docs)
# print(x1_vecs)
# Out:
# [partial failure, total failure, partial failure, total failure, partial failure, total failure, partial failure, total failure, partial failure, total failure, partial failure, total failure, partial failure, total failure, partial failure, total failure, partial failure, total failure, partial failure, total failure, partial failure, total failure, partial failure, total failure, partial failure, total failure, partial failure, total failure, partial failure, total failure, partial failure, total failure, partial failure, total failure, partial failure, total failure, partial failure, total failure, partial failure, total failure, partial failure, total failure, partial failure, total failure, partial failure, total failure, partial failure, total failure, partial failure, total failure, partial failure, total failure, partial failure, total failure, partial failure, total failure, partial failure, total failure, partial failure, total failure, partial failure, total failure, parti
# ...

# %%
docs = [nlp(text) for text in (df['Failure_Condition_2s'])]
# print(docs)
x3_vecs = []
trf = spacy.load('en_core_web_sm')
for doc in trf.pipe(df['Failure_Condition_2s']):
  a = doc.vector
  x3_vecs.append(a)
print(docs)
# print(x1_vecs)
# Out:
# [annuciated, annuciated, annuciated, annuciated, annuciated, annuciated, annuciated, annuciated, unannuciated, unannuciated, unannuciated, unannuciated, unannuciated, unannuciated, unannuciated, unannuciated, annuciated, annuciated, annuciated, annuciated, annuciated, annuciated, annuciated, annuciated, unannuciated, unannuciated, unannuciated, unannuciated, unannuciated, unannuciated, unannuciated, unannuciated, annuciated, annuciated, annuciated, annuciated, annuciated, annuciated, annuciated, annuciated, unannuciated, unannuciated, unannuciated, unannuciated, unannuciated, unannuciated, unannuciated, unannuciated, annuciated, annuciated, annuciated, annuciated, annuciated, annuciated, annuciated, annuciated, unannuciated, unannuciated, unannuciated, unannuciated, unannuciated, unannuciated, unannuciated, unannuciated]

# %%
docs = [nlp(text) for text in (df['Parent_Condition_1s'])]
# print(docs)
x4_vecs = []
trf = spacy.load('en_core_web_sm')
for doc in trf.pipe(df['Parent_Condition_1s']):
  a = doc.vector
  x4_vecs.append(a)
print(docs)
# print(x1_vecs)
# Out:
# [partial failure, partial failure, partial failure, partial failure, partial failure, partial failure, partial failure, partial failure, partial failure, partial failure, partial failure, partial failure, partial failure, partial failure, partial failure, partial failure, total failure, total failure, total failure, total failure, total failure, total failure, total failure, total failure, total failure, total failure, total failure, total failure, total failure, total failure, total failure, total failure, partial failure, partial failure, partial failure, partial failure, partial failure, partial failure, partial failure, partial failure, partial failure, partial failure, partial failure, partial failure, partial failure, partial failure, partial failure, partial failure, total failure, total failure, total failure, total failure, total failure, total failure, total failure, total failure, total failure, total failure, total failure, total failure, total failure, total failure, tot
# ...

# %%
docs = [nlp(text) for text in (df['Parent_Condition_2s'])]
# print(docs)
x5_vecs = []
trf = spacy.load('en_core_web_sm')
for doc in trf.pipe(df['Parent_Condition_2s']):
  a = doc.vector
  x5_vecs.append(a)
print(docs)
# print(x1_vecs)
# Out:
# [annuciated, annuciated, annuciated, annuciated, annuciated, annuciated, annuciated, annuciated, annuciated, annuciated, annuciated, annuciated, annuciated, annuciated, annuciated, annuciated, annuciated, annuciated, annuciated, annuciated, annuciated, annuciated, annuciated, annuciated, annuciated, annuciated, annuciated, annuciated, annuciated, annuciated, annuciated, annuciated, unannuciated, unannuciated, unannuciated, unannuciated, unannuciated, unannuciated, unannuciated, unannuciated, unannuciated, unannuciated, unannuciated, unannuciated, unannuciated, unannuciated, unannuciated, unannuciated, unannuciated, unannuciated, unannuciated, unannuciated, unannuciated, unannuciated, unannuciated, unannuciated, unannuciated, unannuciated, unannuciated, unannuciated, unannuciated, unannuciated, unannuciated, unannuciated]

# %%
docs = [nlp(text) for text in (df['DALs'])]
# print(docs)
x6_vecs = []
trf = spacy.load('en_core_web_sm')
for doc in trf.pipe(df['DALs']):
  a = doc.vector
  x6_vecs.append(a)
print(docs)
# print(x1_vecs)
# Out:
# [none, none, none, none, none, none, none, none, minor, minor, minor, minor, minor, minor, minor, minor, none, none, none, none, none, none, none, none, minor, minor, minor, major, minor, major, minor, major, minor, minor, minor, minor, minor, minor, minor, minor, major, major, major, major, major, major, major, major, minor, major, minor, major, minor, minor, minor, minor, major, hazardous, major, hazardous, major, hazardous, major, hazardous]

# %%
df.head()
# Out:
#   Sub_System Failure_Condition_1s Failure_Condition_2s Parent_Condition_1s  \
# 0          a      partial failure           annuciated     partial failure
# 1          a        total failure           annuciated     partial failure
# 2         b       partial failure           annuciated     partial failure
# 3         b         total failure           annuciated     partial failure
# 4          c      partial failure           annuciated     partial failure
#
#   Parent_Condition_2s  DALs    DAL
# 0          annuciated  none   none
# 1          annuciated  none  minor
# 2          annuciated  none   none
# 3          annuciated  none  minor
# 4          annuciated  none   none

# %%
x1_series = pd.Series(x1_vecs, name='Sub_System')
x2_series = pd.Series(x2_vecs, name='Failure_Condition_1s')
x3_series = pd.Series(x3_vecs, name='Failure_Condition_2s')
x4_series = pd.Series(x4_vecs, name='Parent_Condition_1s')
x5_series = pd.Series(x5_vecs, name='Parent_Condition_2s')
x6_series = pd.Series(x6_vecs, name='DALs')
X_vecs = pd.concat([x1_series, x2_series, x3_series, x4_series, x5_series, x6_series], axis = 1)

X_vecs.head()
# Out:
#                                           Sub_System  \
# 0  [0.44562447, 0.040819645, -1.0442011, 0.977903...
# 1  [0.44562447, 0.040819645, -1.0442011, 0.977903...
# 2  [0.0576514, -0.17174049, -0.10360056, -0.36954...
# 3  [0.0576514, -0.17174049, -0.10360056, -0.36954...
# 4  [0.21607049, -0.2988956, -0.9168757, -0.476875...
#
#                                 Failure_Condition_1s  \
# 0  [-0.49520868, -0.72569513, -0.38544226, 0.6563...
# 1  [-0.6139092, -0.6315098, 0.09689675, 0.4094116...
# 2  [-0.49520868, -0.72569513, -0.38544226, 0.6563...
# 3  [-0.6139092, -0.6315098, 0.09689675, 0.4094116...
# 4  [-0.49520868, -0.72569513, -0.38544226, 0.6563...
#
#                                 Failure_Condition_2s  \
# 0  [-0.7254268, -0.33600435, -0.5738592, -0.16493...
# 1  [-0.7254268, -0.33600435, -0.5738592, -0.16493...
# 2  [-0.7254268, -0.33600435, -0.5738592, -0.16493...
# 3  [-0.7254268, -0.33600435, -0.5738592, -0.16493...
# ...

# %%
X_vecs.isnull().sum()
# Out:
# Sub_System              0
# Failure_Condition_1s    0
# Failure_Condition_2s    0
# Parent_Condition_1s     0
# Parent_Condition_2s     0
# DALs                    0
# dtype: int64

# %%
X_vecs.shape
# Out:
# (64, 6)

# %%
def vector_to_constant(vec):
    vec_array = np.array(vec)
    magnitude = np.linalg.norm(vec_array)
    return magnitude

# %%
X_vecs1 = X_vecs.copy()
for column in X_vecs1.columns:
    # Apply the vector_to_constant function to each entry in the column
    X_vecs1[column] = X_vecs[column].apply(vector_to_constant)
X_vecs1.head()
# Out:
#    Sub_System  Failure_Condition_1s  Failure_Condition_2s  \
# 0    7.576668              5.794087              7.803198
# 1    7.576668              5.765561              7.803198
# 2    7.735302              5.794087              7.803198
# 3    7.735302              5.765561              7.803198
# 4    8.220649              5.794087              7.803198
#
#    Parent_Condition_1s  Parent_Condition_2s      DALs
# 0             5.794087             7.803198  8.090462
# 1             5.794087             7.803198  8.090462
# 2             5.794087             7.803198  8.090462
# 3             5.794087             7.803198  8.090462
# 4             5.794087             7.803198  8.090462

# %%
# X_vecs1.to_csv('X_mag.csv', index=False)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X_vecs1,y,test_size = 0.2, random_state = 42,shuffle = True)
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (51, 6) (51,)
# (13, 6) (13,)

# %%
clf = svm.SVC(kernel='linear')
clf.fit(X_train, y_train)
# Out:
# SVC(kernel='linear')

# %%
clf2 = LogisticRegression()
clf2.fit(X_train,y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
clf3 = DecisionTreeClassifier()
clf3.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_result = clf.predict(X_test)
print(y_result)
# Out:
# ['major' 'hazardous' 'minor' 'hazardous' 'minor' 'major' 'minor' 'major'
#  'major' 'hazardous' 'hazardous' 'major' 'hazardous']

# %%
y_result = clf2.predict(X_test)
print(y_result)
# Out:
# ['major' 'hazardous' 'minor' 'major' 'minor' 'major' 'minor' 'major'
#  'major' 'major' 'hazardous' 'major' 'hazardous']

# %%
y_result = clf3.predict(X_test)
print(y_result)
print(y_test)
# Out:
# ['major' 'hazardous' 'none' 'hazardous' 'minor' 'major' 'minor' 'major'
#  'major' 'catastrophic' 'hazardous' 'major' 'hazardous']
# 52           major
# 58       hazardous
# 0             none
# 44       hazardous
# 5            minor
# 36           major
# 16           minor
# 12           major
# 25           major
# 61    catastrophic
# 56       hazardous
# 9            major
# 40       hazardous
# Name: DAL, dtype: object

# %%
accuracysvm = clf.score(X_test, y_test)
print(f'Test Accuracy: {accuracysvm}')
# Out:
# Test Accuracy: 0.8461538461538461

# %%
accuracyLR = clf2.score(X_test, y_test)
print(f'Test Accuracy: {accuracyLR}')
# Out:
# Test Accuracy: 0.7692307692307693

# %%
accuracyDT = clf3.score(X_test, y_test)
print(f'Test Accuracy: {accuracyDT}')
# Out:
# Test Accuracy: 1.0

# %%
data = {'Sub_System': [], 'Failure_Condition_1s': [], 'Failure_Condition_2s': [],
        'Parent_Condition_1s': [], 'Parent_Condition_2s': [], 'DALs' : []}

inputdf = pd.DataFrame(data)

# %%
user_input = {}
for col in inputdf.columns:
    user_input[col] = input(f"Enter value for {col}: ")
# Append the user input as a new row
inputdf = inputdf.append(user_input, ignore_index=True)
# Out:
# Enter value for Sub_System:
# Enter value for Failure_Condition_1s: s
# Enter value for Failure_Condition_2s: s
# Enter value for Parent_Condition_1s: d
# Enter value for Parent_Condition_2s: h
# Enter value for DALs: hf
# <ipython-input-31-60b7691c0b78>:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   inputdf = inputdf.append(user_input, ignore_index=True)

# %%
inputdf.head()
# Out:
#   Sub_System Failure_Condition_1s Failure_Condition_2s Parent_Condition_1s  \
# 0                               s                    s                   d
#
#   Parent_Condition_2s DALs
# 0                   h   hf
